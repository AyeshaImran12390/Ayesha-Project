# %%
# importing libraries
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/HP/Downloads/HR-Employee-Attrition.csv')

# %%
# displaying max columns 
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# checking the shpe of the dataset
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# checking for the missing values in the dataset
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
age_attrition = df.groupby(['Age','Attrition']).size().reset_index(name='Count')
age_attrition
# Out:
#     Age Attrition  Count
# 0    18        No      4
# 1    18       Yes      4
# 2    19        No      3
# 3    19       Yes      6
# 4    20        No      5
# ..  ...       ...    ...
# 77   57        No      4
# 78   58        No      9
# 79   58       Yes      5
# 80   59        No     10
# 81   60        No      5
#
# [82 rows x 3 columns]

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64'])
numeric_columns = numeric_columns.apply(pd.to_numeric, errors='coerce')
numeric_columns = numeric_columns.fillna(numeric_columns.mean())
correlation = numeric_columns.corr()
plt.figure(figsize=(14,10))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='Age',y='Count',hue='Attrition',data=age_attrition)
plt.title('Age vs Attrition')
plt.show()

# %% [markdown]
#  People with age 28 to 32 are mostly going for attrition while at the later ages there is a stability and people are less seen to gone from the offce

# %%
# checking how income is affecting the attrition 
rate_att=df.groupby(['MonthlyIncome','Attrition']).apply(lambda x:x['MonthlyIncome'].count()).reset_index(name='Counts')
rate_att['MonthlyIncome']=round(rate_att['MonthlyIncome'],-3)
rate_att=rate_att.groupby(['MonthlyIncome','Attrition']).apply(lambda x:x['MonthlyIncome'].count()).reset_index(name='Counts')
plt.figure(figsize=(12, 6))
sns.lineplot(data=rate_att, x='MonthlyIncome', y='Counts', hue='Attrition')
plt.title('Monthly Income vs. Counts of People in an Organization (Attrition)', fontsize=16)
plt.xlabel('Monthly Income (Rounded)', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.legend(title='Attrition', fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# the attrition rate is evidently high at very low income levels- less than 5k monthly.

# %%
df.Department.value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
dep_att = df.groupby(["Department", "Attrition"]).size().reset_index(name='Count')
sns.barplot(x='Department', y='Count', hue='Attrition', data=dep_att)
plt.title('Department vs Attrition')
plt.show()

# %% [markdown]
# The Research development deparmtent has the highest attrition followed by the sales then at last human resources

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
sats_att = df.groupby(['EnvironmentSatisfaction', 'Attrition']).apply(lambda x: x['DailyRate'].count()).reset_index(name='Counts')

plt.figure(figsize=(12, 6))
sns.lineplot(data=sats_att, x='EnvironmentSatisfaction', y='Counts', hue='Attrition', marker='o', palette='Set1')
plt.title('Environment Satisfaction level Counts of People in an Organization', fontsize=16)
plt.xlabel('Environment Satisfaction', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.legend(title='Attrition', fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# In the satisfaction Level 1-2, the chances of peope leaving the organization slightly decreases. This is indicative of the better hopes with which people stay in an organization. However, as we move from 2-3, people tend to move on to get better opportunities and experiences. The attrition rate is almost stagnant for the higher satisfaction levels.

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTUvDbSe8M4DCfpCtdfMZtf9zJAQJD25WSHmA&usqp=CAU)

# %%
Job_satis_attri=df.groupby(['JobSatisfaction','Attrition']).apply(lambda x:x['JobSatisfaction'].count()).reset_index(name='Counts')
sns.lineplot(x='JobSatisfaction',y='Counts',hue='Attrition',data=Job_satis_attri)
plt.title('Job Satisfaction vs Attrition')
plt.show()

# %% [markdown]
# With an increasing job satisfaction, the attrition rates decrease as can be seen in the chart above. Also from range 1-2 range we can infer (as seen above in Environment Satisfaction), the attrition level falls, but raises from 2-3, where the people tend to coose better opportunities.

# %%
stock_attrition = df.groupby(['StockOptionLevel', 'Attrition']).apply(lambda x: x['DailyRate'].count()).reset_index(name='Counts')
sns.barplot(data=stock_attrition, x='StockOptionLevel', y='Counts', hue='Attrition')
plt.title('Stock Option Level vs Attrition')
plt.show()

# %% [markdown]
# The tendency of employees to leave the organization is much more when the stock availing options are limited. Since the stocks constitute to a huge amount of money while staying for a few years, people do not want to lose that opportunity. People with very limited/no stcok options have a freedom to leave the organization at will.

# %%
df.WorkLifeBalance.value_counts()
# Out:
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64

# %%
work_life_b_att=df.groupby(['WorkLifeBalance','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
sns.barplot(data=work_life_b_att,x='WorkLifeBalance',y='Counts',hue='Attrition')
plt.title('Work Life Balance vs Attrition')
plt.show()

# %% [markdown]
# People with poor levels of Work life balance have adjusted themselves to their jobs, but as seen for the above parameters with a better work life score, people are looking towards the better life and want to go for an attrition more. But this trend perishes when the work life balance is really good, and people are satisfied with the work they are doing

# %% [markdown]
# ![](https://m.jagranjosh.com/imported/images/E/Articles/imp-of-work-ex.jpg)

# %%
ncwrd_att=df.groupby(['NumCompaniesWorked','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
sns.lineplot(data=ncwrd_att,x='NumCompaniesWorked',y='Counts',hue='Attrition')
plt.title('Number of Companies Worked vs Attrition')
plt.show()

# %% [markdown]
# As seen from the chart above, clearly, employees who started their career with the company- or have switched to the company in the initial years of their career, have a higher chances of leaving the organization to a different company. People who have gained much experience- working in multiple companies tend to stay in the company they join.

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
years_served_att=df.groupby(['YearsInCurrentRole','Attrition']).size().reset_index(name='Counts')
sns.lineplot(data=years_served_att,x='YearsInCurrentRole',y='Counts',hue='Attrition')
plt.title('Years in Current Role vs Attrition')
plt.show()

# %% [markdown]
# We have seen people are more prone to leave the organization in the starting years on their role. When people are in the same role for a long period of time, they tend to stay longer for moving in an upward role.

# %% [markdown]
# ![](https://m.jagranjosh.com/imported/images/E/Articles/5-simple-ways-to-ask.jpg)

# %%
salary_hike_att=df.groupby(['PercentSalaryHike','Attrition']).size().reset_index(name='Counts')
sns.lineplot(data=salary_hike_att,x='PercentSalaryHike',y='Counts',hue='Attrition')
plt.title('Percent Salary Hike vs Attrition')
plt.show()

# %% [markdown]
# Higher hikes motivate people to work better, and stay in the organization. Hence we see the chances of an employee leaving the organization where the hike is lower, is much more than a company that gives a good hike.

# %%
managers_att=df.groupby(['YearsWithCurrManager','Attrition']).size().reset_index(name='Counts')
sns.lineplot(data=managers_att,x='YearsWithCurrManager',y='Counts',hue='Attrition')
plt.title('Years with Current Manager vs Attrition')
plt.show()

# %% [markdown]
# There are three major spikes. first is as people are working with a new manager they tend to attirtion more quickly the second is after spending 7 8 years they tend to change. they might do this to have some more other perspective or mentroship and after that the attrition rate is much less as compared to inital stages.

# %% [markdown]
# ### Training the model using the insights and after observing all the relation of the columns with the attrition columns

# %%
# improting logistic regression model 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X=df[['Age', 'DailyRate',
       'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction',
        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction','StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]
y=df[['Attrition']].values.ravel() 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
log_reg=LogisticRegression(C=1000,max_iter=10000)
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1000, max_iter=10000)

# %%
# let's test this on the test data
y_pred = log_reg.predict(X_test)

# %%
# let's check how well our model is performing by using perfromace metrics
# from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Assuming y_test is the true labels and y_pred are predictions
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=log_reg.classes_)
disp.plot(cmap='viridis')
plt.title("Confusion Matrix")
plt.show()

# %%
#The model is very good at predicting no but it is making mistakes in predicting yes. so workng more deeply on the model can increase the accuracy
#up to 90% or more.

# %%
# let's check its accuracy score 
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8299319727891157

# %%
## The model has a decent accuracy of 0.83 which is good.

# %% [markdown]
# ![](https://images.squarespace-cdn.com/content/v1/5949fa712994cac7d8ebd5f3/1544567194263-BX0S7PVPZU4PC8SC9CGO/ke17ZwdGBToddI8pDm48kAqSCtZ9RC6QXaK0A8UwWmhZw-zPPgdn4jUwVcJE1ZvWEtT5uBSRWt4vQZAgTJucoTqqXjS3CfNDSuuf31e0tVEHY6Goe095UwrRcBaZ48jcvr1vIHfdQnnc9Te-C7rAhJuG45vQwBxdpDrCGUSSl5w/90percent.png)

# %%
from sklearn.metrics import  mean_squared_error,r2_score

# %%
def convert_to_numeric(data):
    from sklearn.preprocessing import LabelEncoder
    label_encoder = LabelEncoder()
    return label_encoder.fit_transform(data)
y_test_numeric = convert_to_numeric(y_test)
y_pred_numeric = convert_to_numeric(y_pred)

# Calculate RMSE
mse = mean_squared_error(y_test_numeric, y_pred_numeric)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Squared Error (MSE): 0.17006802721088435
# Root Mean Squared Error (RMSE): 0.41239304942116123

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test_numeric, y_pred_numeric)
precision = precision_score(y_test_numeric, y_pred_numeric)
recall = recall_score(y_test_numeric, y_pred_numeric)
f1 = f1_score(y_test_numeric, y_pred_numeric)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.8299319727891157
# Precision: 0.46153846153846156
# Recall: 0.12244897959183673
# F1 Score: 0.1935483870967742
